# %%
import numpy as np
import pandas as pd
# yaml to pandas
from yaml import safe_load
import os
from tqdm import tqdm

# %%
filenames = []
for file in os.listdir('t20s'):
    filenames.append(os.path.join('t20s',file))

# %%
filenames[0:5]
# Out:
# ['t20s\\1072322.yaml',
#  't20s\\1074957.yaml',
#  't20s\\1074958.yaml',
#  't20s\\1074959.yaml',
#  't20s\\1074961.yaml']

# %%
final_df = pd.DataFrame()
counter = 1
for file in tqdm(filenames):
    with open(file, 'r') as f:
        df = pd.json_normalize(safe_load(f))
        df['match_id'] = counter
        final_df = final_df.append(df)
        counter+=1
        
final_df
# Out:
#   0%|                                                                                         | 0/1392 [00:00<?, ?it/s]C:\Users\SOUVIK MONDAL\AppData\Local\Temp\ipykernel_1664\2042649833.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_df = final_df.append(df)
#   0%|                                                                                 | 1/1392 [00:01<34:26,  1.49s/it]C:\Users\SOUVIK MONDAL\AppData\Local\Temp\ipykernel_1664\2042649833.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_df = final_df.append(df)
# ...

# %%
backup = final_df.copy()

# %%
final_df
# Out:
#                                               innings  meta.data_version  \
# 0   [{'1st innings': {'team': 'New Zealand', 'deli...                0.9
# 0   [{'1st innings': {'team': 'Scotland', 'deliver...                0.9
# 0   [{'1st innings': {'team': 'Ireland', 'deliveri...                0.9
# 0   [{'1st innings': {'team': 'Oman', 'deliveries'...                0.9
# 0   [{'1st innings': {'team': 'Hong Kong', 'delive...                0.9
# ..                                                ...                ...
# 0   [{'1st innings': {'team': 'Sri Lanka', 'delive...                0.9
# 0   [{'1st innings': {'team': 'Bangladesh', 'deliv...                0.9
# 0   [{'1st innings': {'team': 'Netherlands', 'deli...                0.9
# 0   [{'1st innings': {'team': 'Australia', 'delive...                0.9
# 0   [{'1st innings': {'team': 'Sri Lanka', 'delive...                0.9
#
#    meta.created  meta.revision  info.city    info.dates info.gender  \
# ...

# %%
# drop unnecessary colums  
final_df.drop(columns=[
    'meta.data_version',
    'meta.created',
    'meta.revision',
    'info.outcome.bowl_out',
    'info.bowl_out',
    'info.supersubs.South Africa',
    'info.supersubs.New Zealand',
    'info.outcome.eliminator',
    'info.outcome.result',
    'info.outcome.method',
    'info.neutral_venue',
    'info.match_type_number',
    'info.outcome.by.runs',
    'info.outcome.by.wickets'
],inplace=True)

# %%
final_df
# Out:
#                                               innings  info.city  \
# 0   [{'1st innings': {'team': 'New Zealand', 'deli...   Auckland
# 0   [{'1st innings': {'team': 'Scotland', 'deliver...  Abu Dhabi
# 0   [{'1st innings': {'team': 'Ireland', 'deliveri...  Abu Dhabi
# 0   [{'1st innings': {'team': 'Oman', 'deliveries'...  Abu Dhabi
# 0   [{'1st innings': {'team': 'Hong Kong', 'delive...  Abu Dhabi
# ..                                                ...        ...
# 0   [{'1st innings': {'team': 'Sri Lanka', 'delive...     Mirpur
# 0   [{'1st innings': {'team': 'Bangladesh', 'deliv...     Mirpur
# 0   [{'1st innings': {'team': 'Netherlands', 'deli...      Dubai
# 0   [{'1st innings': {'team': 'Australia', 'delive...        NaN
# 0   [{'1st innings': {'team': 'Sri Lanka', 'delive...    Colombo
#
#       info.dates info.gender info.match_type info.outcome.winner  info.overs  \
# 0   [2018-02-21]        male             T20           Australia          20
# ...

# %%
final_df['info.gender'].value_counts()
# Out:
# male      931
# female    460
# Name: info.gender, dtype: int64

# %%
# filtering only matches played by male
final_df = final_df[final_df['info.gender'] == 'male']
final_df.drop(columns=['info.gender'],inplace=True)
final_df
# Out:
# C:\Users\SOUVIK MONDAL\AppData\Local\Temp\ipykernel_1664\2064457333.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   final_df.drop(columns=['info.gender'],inplace=True)
#                                               innings  info.city  \
# 0   [{'1st innings': {'team': 'New Zealand', 'deli...   Auckland
# 0   [{'1st innings': {'team': 'Scotland', 'deliver...  Abu Dhabi
# 0   [{'1st innings': {'team': 'Ireland', 'deliveri...  Abu Dhabi
# 0   [{'1st innings': {'team': 'Oman', 'deliveries'...  Abu Dhabi
# 0   [{'1st innings': {'team': 'Hong Kong', 'delive...  Abu Dhabi
# ..                                                ...        ...
# 0   [{'1st innings': {'team': 'Sri Lanka', 'delive...     Mirpur
# 0   [{'1st innings': {'team': 'Bangladesh', 'deliv...     Mirpur
# ...

# %%
# info.match_type - contains only T20 so need of that column
final_df['info.match_type'].value_counts()
# Out:
# T20    931
# Name: info.match_type, dtype: int64

# %%
final_df['info.overs'].value_counts()
# Out:
# 20    928
# 50      3
# Name: info.overs, dtype: int64

# %%
# filter out the matches which have only 20 overs
final_df = final_df[final_df['info.overs'] == 20]
# dropping both the columns
final_df.drop(columns=['info.overs','info.match_type'],inplace=True)
final_df
# Out:
# C:\Users\SOUVIK MONDAL\AppData\Local\Temp\ipykernel_1664\1877991516.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   final_df.drop(columns=['info.overs','info.match_type'],inplace=True)
#                                               innings  info.city  \
# 0   [{'1st innings': {'team': 'New Zealand', 'deli...   Auckland
# 0   [{'1st innings': {'team': 'Scotland', 'deliver...  Abu Dhabi
# 0   [{'1st innings': {'team': 'Ireland', 'deliveri...  Abu Dhabi
# 0   [{'1st innings': {'team': 'Oman', 'deliveries'...  Abu Dhabi
# 0   [{'1st innings': {'team': 'Hong Kong', 'delive...  Abu Dhabi
# ..                                                ...        ...
# 0   [{'1st innings': {'team': 'Sri Lanka', 'delive...     Mirpur
# 0   [{'1st innings': {'team': 'Bangladesh', 'deliv...     Mirpur
# ...

# %%
import pickle
pickle.dump(final_df,open('dataset_level1.pkl','wb'))

# %%
matches = pickle.load(open('dataset_level1.pkl','rb'))
matches
# matches.iloc[0]['innings'][0]['1st innings']['deliveries']
# Out:
#                                               innings  info.city  \
# 0   [{'1st innings': {'team': 'New Zealand', 'deli...   Auckland
# 0   [{'1st innings': {'team': 'Scotland', 'deliver...  Abu Dhabi
# 0   [{'1st innings': {'team': 'Ireland', 'deliveri...  Abu Dhabi
# 0   [{'1st innings': {'team': 'Oman', 'deliveries'...  Abu Dhabi
# 0   [{'1st innings': {'team': 'Hong Kong', 'delive...  Abu Dhabi
# ..                                                ...        ...
# 0   [{'1st innings': {'team': 'Sri Lanka', 'delive...     Mirpur
# 0   [{'1st innings': {'team': 'Bangladesh', 'deliv...     Mirpur
# 0   [{'1st innings': {'team': 'Netherlands', 'deli...      Dubai
# 0   [{'1st innings': {'team': 'Australia', 'delive...        NaN
# 0   [{'1st innings': {'team': 'Sri Lanka', 'delive...    Colombo
#
#       info.dates info.outcome.winner info.player_of_match  \
# 0   [2018-02-21]           Australia            [AC Agar]
# 0   [2017-01-14]            Scotland         [CS MacLeod]
# ...

# %%
count = 1
delivery_df = pd.DataFrame()
for index, row in matches.iterrows():
    if count in [75,108,150,180,268,360,443,458,584,748,982,1052,1111,1226,1345]:
        count+=1
        continue
    count+=1
    ball_of_match = []
    batsman = []
    bowler = []
    runs = []
    player_of_dismissed = []
    teams = []
    batting_team = []
    match_id = []
    city = []
    venue = []
    for ball in row['innings'][0]['1st innings']['deliveries']:
        for key in ball.keys():
            match_id.append(count)
            batting_team.append(row['innings'][0]['1st innings']['team'])
            teams.append(row['info.teams'])
            ball_of_match.append(key)
            batsman.append(ball[key]['batsman'])
            bowler.append(ball[key]['bowler'])
            runs.append(ball[key]['runs']['total'])
            city.append(row['info.city'])
            venue.append(row['info.venue'])
            try:
                player_of_dismissed.append(ball[key]['wicket']['player_out'])
            except:
                player_of_dismissed.append('0')
    loop_df = pd.DataFrame({
            'match_id':match_id,
            'teams':teams,
            'batting_team':batting_team,
            'ball':ball_of_match,
            'batsman':batsman,
            'bowler':bowler,
            'runs':runs,
            'player_dismissed':player_of_dismissed,
            'city':city,
            'venue':venue
        })
    delivery_df = delivery_df.append(loop_df)
# Out:
# C:\Users\SOUVIK MONDAL\AppData\Local\Temp\ipykernel_1664\3780558368.py:45: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   delivery_df = delivery_df.append(loop_df)
# C:\Users\SOUVIK MONDAL\AppData\Local\Temp\ipykernel_1664\3780558368.py:45: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   delivery_df = delivery_df.append(loop_df)
# C:\Users\SOUVIK MONDAL\AppData\Local\Temp\ipykernel_1664\3780558368.py:45: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   delivery_df = delivery_df.append(loop_df)
# C:\Users\SOUVIK MONDAL\AppData\Local\Temp\ipykernel_1664\3780558368.py:45: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# ...

# %%
delivery_df
# Out:
#      match_id                     teams batting_team  ball          batsman  \
# 0           2  [New Zealand, Australia]  New Zealand   0.1       MJ Guptill
# 1           2  [New Zealand, Australia]  New Zealand   0.2          C Munro
# 2           2  [New Zealand, Australia]  New Zealand   0.3          C Munro
# 3           2  [New Zealand, Australia]  New Zealand   0.4       MJ Guptill
# 4           2  [New Zealand, Australia]  New Zealand   0.5       MJ Guptill
# ..        ...                       ...          ...   ...              ...
# 121       929    [Sri Lanka, Australia]    Sri Lanka  19.3  SMSM Senanayake
# 122       929    [Sri Lanka, Australia]    Sri Lanka  19.4      DM de Silva
# 123       929    [Sri Lanka, Australia]    Sri Lanka  19.5      DM de Silva
# 124       929    [Sri Lanka, Australia]    Sri Lanka  19.6  SMSM Senanayake
# 125       929    [Sri Lanka, Australia]    Sri Lanka  19.7  SMSM Senanayake
#
# ...

# %%
# to extract bowling team name
def bowl(row):
    for team in row['teams']:
        if team != row['batting_team']:
            return team

# %%
# adding the bolwing team column
delivery_df['bowling_team'] = delivery_df.apply(bowl,axis=1)

# %%
delivery_df
# Out:
#      match_id                     teams batting_team  ball          batsman  \
# 0           2  [New Zealand, Australia]  New Zealand   0.1       MJ Guptill
# 1           2  [New Zealand, Australia]  New Zealand   0.2          C Munro
# 2           2  [New Zealand, Australia]  New Zealand   0.3          C Munro
# 3           2  [New Zealand, Australia]  New Zealand   0.4       MJ Guptill
# 4           2  [New Zealand, Australia]  New Zealand   0.5       MJ Guptill
# ..        ...                       ...          ...   ...              ...
# 121       929    [Sri Lanka, Australia]    Sri Lanka  19.3  SMSM Senanayake
# 122       929    [Sri Lanka, Australia]    Sri Lanka  19.4      DM de Silva
# 123       929    [Sri Lanka, Australia]    Sri Lanka  19.5      DM de Silva
# 124       929    [Sri Lanka, Australia]    Sri Lanka  19.6  SMSM Senanayake
# 125       929    [Sri Lanka, Australia]    Sri Lanka  19.7  SMSM Senanayake
#
# ...

# %%
# drop teams as not needed now
delivery_df.drop(columns=['teams'],inplace=True)

# %%
delivery_df['batting_team'].unique()
# Out:
# array(['New Zealand', 'Scotland', 'Ireland', 'Oman', 'Hong Kong',
#        'United Arab Emirates', 'South Africa', 'West Indies', 'Pakistan',
#        'Bangladesh', 'Papua New Guinea', 'Afghanistan', 'India',
#        'Sri Lanka', 'Australia', 'England', 'Zimbabwe', 'Netherlands',
#        'Nepal', 'Vanuatu', 'Philippines', 'United States of America',
#        'Germany', 'Ghana', 'Uganda', 'Kenya', 'Namibia', 'Nigeria',
#        'Botswana', 'Guernsey', 'Denmark', 'Jersey', 'Italy', 'Norway',
#        'Thailand', 'Malaysia', 'Maldives', 'Singapore', 'Kuwait',
#        'Bermuda', 'Canada', 'Cayman Islands', 'Portugal', 'Gibraltar',
#        'Spain', 'Bhutan', 'Qatar', 'Iran', 'Belgium', 'Isle of Man',
#        'Bulgaria', 'Romania'], dtype=object)

# %%
# selecting top 10 teams
teams = [
    'Australia',
    'India',
    'Bangladesh',
    'New Zealand',
    'South Africa',
    'England',
    'West Indies',
    'Afghanistan',
    'Pakistan',
    'Sri Lanka'    
]

# %%
# filter only those teams which are in top 10
delivery_df = delivery_df[delivery_df['batting_team'].isin(teams)]
delivery_df = delivery_df[delivery_df['bowling_team'].isin(teams)]

# %%
delivery_df
# Out:
#      match_id batting_team  ball          batsman      bowler  runs  \
# 0           2  New Zealand   0.1       MJ Guptill  B Stanlake     2
# 1           2  New Zealand   0.2          C Munro  B Stanlake     0
# 2           2  New Zealand   0.3          C Munro  B Stanlake     1
# 3           2  New Zealand   0.4       MJ Guptill  B Stanlake     0
# 4           2  New Zealand   0.5       MJ Guptill  B Stanlake     1
# ..        ...          ...   ...              ...         ...   ...
# 121       929    Sri Lanka  19.3  SMSM Senanayake    MA Starc     1
# 122       929    Sri Lanka  19.4      DM de Silva    MA Starc     0
# 123       929    Sri Lanka  19.5      DM de Silva    MA Starc     0
# 124       929    Sri Lanka  19.6  SMSM Senanayake    MA Starc     2
# 125       929    Sri Lanka  19.7  SMSM Senanayake    MA Starc     1
#
#     player_dismissed      city                venue bowling_team
# 0                  0  Auckland            Eden Park    Australia
# ...

# %%
# extracting the needed columns and putting into output 
output = delivery_df[['match_id','batting_team','bowling_team','ball','runs','player_dismissed','city','venue']]

# %%
output
# Out:
#      match_id batting_team bowling_team  ball  runs player_dismissed  \
# 0           2  New Zealand    Australia   0.1     2                0
# 1           2  New Zealand    Australia   0.2     0                0
# 2           2  New Zealand    Australia   0.3     1                0
# 3           2  New Zealand    Australia   0.4     0                0
# 4           2  New Zealand    Australia   0.5     1                0
# ..        ...          ...          ...   ...   ...              ...
# 121       929    Sri Lanka    Australia  19.3     1                0
# 122       929    Sri Lanka    Australia  19.4     0                0
# 123       929    Sri Lanka    Australia  19.5     0      DM de Silva
# 124       929    Sri Lanka    Australia  19.6     2                0
# 125       929    Sri Lanka    Australia  19.7     1                0
#
#          city                venue
# 0    Auckland            Eden Park
# 1    Auckland            Eden Park
# ...

# %%
# pickling the output so that from later we can start from here
pickle.dump(output,open('dataset_level2.pkl','wb'))
